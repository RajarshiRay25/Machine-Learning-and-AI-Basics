# %%
import pandas as pd

# %%
dataset = pd.read_csv("F://JUPYTER-CODE//Machine-Learning-and-AI-Basics//datasheet.csv")
dataset
# Out:
#      Name  Age    Language
# 0     Raj   20      Python
# 1   Alice   19        Java
# 2     Sky   21           C
# 3   Shawn   25  Javascript
# 4    Shaw   25     Not ava
# 5    Shan   26         NaN
# 6    Shwn   29  Javascript
# 7   Shawn  215         NaN
# 8    Shwn   25  Javascript
# 9   Shawn   25  Javascript
# 10  Shawn   25  Javascript

# %%
# If theres a null or NA value show it by
dataset = pd.read_csv("F://JUPYTER-CODE//Machine-Learning-and-AI-Basics//datasheet.csv")
dataset
# Out:
#      Name  Age    Language
# 0     Raj   20      Python
# 1   Alice   19        Java
# 2     Sky   21           C
# 3   Shawn   25  Javascript
# 4    Shaw   25     Not ava
# 5    Shan   26         NaN
# 6    Shwn   29  Javascript
# 7   Shawn  215         NaN
# 8    Shwn   25  Javascript
# 9   Shawn   25  Javascript
# 10  Shawn   25  Javascript

# %%
# If any other value except blanks in CSV
# eg - Not ava
dataset = pd.read_csv("F://JUPYTER-CODE//Machine-Learning-and-AI-Basics//datasheet.csv",na_values="Not ava")
dataset
# Out:
#      Name  Age    Language
# 0     Raj   20      Python
# 1   Alice   19        Java
# 2     Sky   21           C
# 3   Shawn   25  Javascript
# 4    Shaw   25         NaN
# 5    Shan   26         NaN
# 6    Shwn   29  Javascript
# 7   Shawn  215         NaN
# 8    Shwn   25  Javascript
# 9   Shawn   25  Javascript
# 10  Shawn   25  Javascript

# %%
# To check null values in file

dataset.isnull()
# Out:
#      Name    Age  Language
# 0   False  False     False
# 1   False  False     False
# 2   False  False     False
# 3   False  False     False
# 4   False  False      True
# 5   False  False      True
# 6   False  False     False
# 7   False  False      True
# 8   False  False     False
# 9   False  False     False
# 10  False  False     False

# %%
# To check numbers of nulls in each column

dataset.isnull().sum()
# Out:
# Name        0
# Age         0
# Language    3
# dtype: int64

# %%
# Total all over NULLS 

dataset.isnull().sum().sum()
# Out:
# 3

# %%
# To check non null values

dataset.notnull()
# Out:
#     Name   Age  Language
# 0   True  True      True
# 1   True  True      True
# 2   True  True      True
# 3   True  True      True
# 4   True  True     False
# 5   True  True     False
# 6   True  True      True
# 7   True  True     False
# 8   True  True      True
# 9   True  True      True
# 10  True  True      True

# %%
# To check non nulls in each column

dataset.notnull().sum()
# Out:
# Name        11
# Age         11
# Language     8
# dtype: int64

# %%
# To check all total non nulls

dataset.notnull().sum().sum()
# Out:
# 30

# %%
# Using numpy and series

import numpy as np

dataser = pd.Series([1,2,3,4,np.nan,3,np.NAN])
dataser
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    3.0
# 6    NaN
# dtype: float64

# %%
dataser.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# dtype: bool

# %%
dataser.isnull().sum()
# Out:
# 2

# %%
dataser.isnull().sum().sum()
# Out:
# 2

# %%
dataser.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
dataser.notnull().sum()
# Out:
# 5

# %%
dataser.notnull().sum().sum()
# Out:
# 5

# %%
# to remove all values with na or N/A

dataset = pd.read_csv("F://JUPYTER-CODE//Machine-Learning-and-AI-Basics//datasheet.csv",na_values="Not ava")
dataset.dropna()
# Out:
#      Name  Age    Language
# 0     Raj   20      Python
# 1   Alice   19        Java
# 2     Sky   21           C
# 3   Shawn   25  Javascript
# 6    Shwn   29  Javascript
# 8    Shwn   25  Javascript
# 9   Shawn   25  Javascript
# 10  Shawn   25  Javascript

# %%
dataset = pd.read_csv("F://JUPYTER-CODE//Machine-Learning-and-AI-Basics//datasheet.csv",na_values="Not ava")
dataset
# Out:
#      Name  Age    Language
# 0     Raj   20      Python
# 1   Alice   19        Java
# 2     Sky   21           C
# 3   Shawn   25  Javascript
# 4    Shaw   25         NaN
# 5    Shan   26         NaN
# 6    Shwn   29  Javascript
# 7   Shawn  215         NaN
# 8    Shwn   25  Javascript
# 9   Shawn   25  Javascript
# 10  Shawn   25  Javascript
