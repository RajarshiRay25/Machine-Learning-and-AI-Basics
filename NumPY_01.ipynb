# %%
import numpy as np

# %%
arr_1 = np.array([1,2,3,4])
print(arr_1)
# Out:
# [1 2 3 4]

# %%
arr_2 = np.array([[1,2,3,4],[5,6,7,8]])
print(arr_2)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
type(arr_2)
# Out:
# numpy.ndarray

# %%
arr_2.shape #row vs col
# Out:
# (2, 4)

# %%
arr_2.size #elem_no.
# Out:
# 8

# %%
arr_2.ndim #dimension
# Out:
# 2
