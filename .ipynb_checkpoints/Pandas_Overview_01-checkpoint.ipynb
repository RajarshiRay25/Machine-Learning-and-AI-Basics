# %%
import pandas as pd

# %%
# Create a dictionary to analyse
names_data = {
    "Name" : ["Raj","Roy","Sky","Jay"],
    "Age"  : [20,21,22,23],
    "Language" : ["Py","C","JS","R"]
}

# %%
names_data
# Out:
# {'Name': ['Raj', 'Roy', 'Sky', 'Jay'],
#  'Age': [20, 21, 22, 23],
#  'Language': ['Py', 'C', 'JS', 'R']}

# %%
dataFrame = pd.DataFrame(names_data)   # Convert to dataset 
dataFrame
# Out:
#   Name  Age Language
# 0  Raj   20       Py
# 1  Roy   21        C
# 2  Sky   22       JS
# 3  Jay   23        R

# %%
dataFrame.to_csv("my_data")   # indexed data

# %%
dataFrame = pd.DataFrame(names_data)   # Convert to dataset 
dataFrame
# Out:
#   Name  Age Language
# 0  Raj   20       Py
# 1  Roy   21        C
# 2  Sky   22       JS
# 3  Jay   23        R

# %%
dataFrame.to_csv("my_data_nocsv",index=False)  # no index

# %%
dataFrame = pd.DataFrame(names_data)   # Convert to dataset 
dataFrame
# Out:
#   Name  Age Language
# 0  Raj   20       Py
# 1  Roy   21        C
# 2  Sky   22       JS
# 3  Jay   23        R

# %%
dataFrame.head(2)   # First elements view
# Out:
#   Name  Age Language
# 0  Raj   20       Py
# 1  Roy   21        C

# %%
dataFrame.tail(2)  # Last elements view
# Out:
#   Name  Age Language
# 2  Sky   22       JS
# 3  Jay   23        R

# %%
dataFrame.describe()   # if table has integer value columns returns statistical information
# Out:
#              Age
# count   4.000000
# mean   21.500000
# std     1.290994
# min    20.000000
# 25%    20.750000
# 50%    21.500000
# 75%    22.250000
# max    23.000000
